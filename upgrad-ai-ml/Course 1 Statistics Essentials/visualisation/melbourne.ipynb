# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('melbourne.csv')
df.isna().any()
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %%
df[df.isna().sum(axis=1) <= 5]
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23541  Williamstown        96 Verdon St      4    h  2500000.0     PI
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/4XobYYebXE8neXERGebxyEY4y/market_fact.csv')
df.loc[df['Product_Base_Margin'].isna(), ['Product_Base_Margin']] = 0.512481
print(round(100*((df.isna().sum())/(df.index.size)), 2))
# Out:
# Ord_id                 0.00
# Prod_id                0.00
# Ship_id                0.00
# Cust_id                0.00
# Sales                  0.24
# Discount               0.65
# Order_Quantity         0.65
# Profit                 0.65
# Shipping_Cost          0.65
# Product_Base_Margin    0.00
# dtype: float64
